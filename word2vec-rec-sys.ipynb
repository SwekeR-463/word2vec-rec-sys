# %%
#!pip install gensim

# %%
import numpy as np
import pandas as pd

# %%
anime_df = pd.read_csv('/kaggle/input/anime-recommendations-database/anime.csv')
rating_df = pd.read_csv('/kaggle/input/anime-recommendations-database/rating.csv')

# %%
anime_df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
rating_df.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %% [markdown]
# #### here there are -1 ratings so filtering out these ratings first

# %%
rating_df = rating_df[rating_df["rating"] != -1]
rating_df.head()
# Out:
#      user_id  anime_id  rating
# 47         1      8074      10
# 81         1     11617      10
# 83         1     11757      10
# 101        1     15451      10
# 153        2     11771      10

# %% [markdown]
# #### merging both

# %%
df = pd.merge(rating_df, anime_df, on="anime_id")

# %%
df.head()
# Out:
#    user_id  anime_id  rating_x                    name  \
# 0        1      8074        10  Highschool of the Dead
# 1        3      8074         6  Highschool of the Dead
# 2        5      8074         2  Highschool of the Dead
# 3       12      8074         6  Highschool of the Dead
# 4       14      8074         6  Highschool of the Dead
#
#                                  genre type episodes  rating_y  members
# 0  Action, Ecchi, Horror, Supernatural   TV       12      7.46   535892
# 1  Action, Ecchi, Horror, Supernatural   TV       12      7.46   535892
# 2  Action, Ecchi, Horror, Supernatural   TV       12      7.46   535892
# 3  Action, Ecchi, Horror, Supernatural   TV       12      7.46   535892
# 4  Action, Ecchi, Horror, Supernatural   TV       12      7.46   535892

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6337239 entries, 0 to 6337238
# Data columns (total 9 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating_x  int64
#  3   name      object
#  4   genre     object
#  5   type      object
#  6   episodes  object
#  7   rating_y  float64
#  8   members   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 435.1+ MB

# %% [markdown]
# #### checking upon the non values and getting rid of them

# %%
df.isna().sum()
# Out:
# user_id      0
# anime_id     0
# rating_x     0
# name         0
# genre       88
# type         4
# episodes     0
# rating_y     5
# members      0
# dtype: int64

# %%
df = df.dropna(subset=["genre"])
df.isna().sum()
# Out:
# user_id     0
# anime_id    0
# rating_x    0
# name        0
# genre       0
# type        4
# episodes    0
# rating_y    5
# members     0
# dtype: int64

# %% [markdown]
# #### making the rec sys based on genres

# %% [markdown]
# #### tokenizing the genre column

# %%
df["genre_tokens"] = df["genre"].apply(lambda x: x.split(", "))

# %%
genre_sentences = df["genre_tokens"].tolist()

# %% [markdown]
# ### training the word2vec model

# %%
from gensim.models import Word2Vec

w2v = Word2Vec(sentences=genre_sentences, vector_size=100, window=5, min_count=1, workers=4)

# %% [markdown]
# #### gensim has many prebuilt functions making it easy

# %%
similar_genres = w2v.wv.most_similar("Action", topn=5)
print("Genres similar to 'Action':", similar_genres)
# Out:
# Genres similar to 'Action': [('Kids', 0.26868152618408203), ('Shounen', 0.19272707402706146), ('Romance', 0.15925388038158417), ('Music', 0.13184012472629547), ('Space', 0.10436685383319855)]

# %% [markdown]
# #### recommending anime names based on their genres

# %%
def recommend_anime_by_genre(genre):
    similar_genres = [g[0] for g in w2v.wv.most_similar(genre, topn=5)]
    recommendations = df[df["genre"].str.contains("|".join(similar_genres))]
    return recommendations[["name", "genre"]].drop_duplicates()

# %%
recommendations = recommend_anime_by_genre("Ecchi")
recommendations
# Out:
#                                        name  \
# 19488                       High School DxD
# 31628                      Sword Art Online
# 57938                   High School DxD New
# 65665                      Kuroko no Basket
# 103692                            Slam Dunk
# ...                                     ...
# 6337225    Asari-chan: Ai no Marchen Shoujo
# 6337226       Shiratori Reiko de Gozaimasu!
# 6337227                        Cooking Papa
# 6337234  Haha wo Tazunete Sanzenri Specials
# 6337235      Fushigi na Somera-chan Special
#
#                                                      genre
# 19488        Comedy, Demons, Ecchi, Harem, Romance, School
# 31628            Action, Adventure, Fantasy, Game, Romance
# 57938    Action, Comedy, Demons, Ecchi, Harem, Romance,...
# 65665                      Comedy, School, Shounen, Sports
# 103692              Comedy, Drama, School, Shounen, Sports
# ...                                                    ...
# 6337225                   Adventure, Shoujo, Slice of Life
# 6337226                                    Comedy, Romance
# 6337227                              Comedy, Slice of Life
# 6337234                    Adventure, Drama, Slice of Life
# 6337235                       Comedy, Magic, Slice of Life
#
# [3287 rows x 2 columns]

# %% [markdown]
# #### making the same for anime names

# %% [markdown]
# #### see so many animes :)

# %%
anime_names = df["name"].unique()
anime_names[:69]
# Out:
# array(['Highschool of the Dead', 'High School DxD', 'Sword Art Online',
#        'High School DxD New', 'Kuroko no Basket', 'Naruto', 'Shaman King',
#        'Slam Dunk', 'Sen to Chihiro no Kamikakushi', 'Dragon Ball GT',
#        'Spiral: Suiri no Kizuna',
#        'Fullmetal Alchemist: The Conqueror of Shamballa', 'Pokemon',
#        'Digimon Adventure', 'Dragon Ball Z',
#        'Pokemon: Celebi Toki wo Koeta Deai',
#        'Pokemon Advanced Generation: Nanayo no Negaiboshi Jirachi',
#        'Pokemon Advanced Generation: Rekkuu no Houmonsha Deoxys',
#        'Digimon Frontier', 'Afro Samurai', 'Digimon Adventure 02',
#        'Pokemon Advanced Generation: Mew to Hadou no Yuusha Lucario',
#        'Death Note', 'Pokemon Advanced Generation',
#        'Byousoku 5 Centimeter', 'Slam Dunk (Movie)', 'Paprika',
#        'Pokemon Advanced Generation: Pokemon Ranger to Umi no Ouji Manaphy',
#        'Zombie-Loan',
#        'Pokemon Diamond &amp; Pearl: Dialga vs. Palkia vs. Darkrai',
#        'Soul Eater',
#        'Pokemon Diamond &amp; Pearl: Giratina to Sora no Hanataba Sheimi',
#        'Fullmetal Alchemist: Brotherhood', 'Inazuma Eleven',
#        'Pokemon Diamond &amp; Pearl: Arceus Choukoku no Jikuu e',
#        'Fairy Tail', 'Deadman Wonderland',
#        'Pokemon Diamond &amp; Pearl: Genei no Hasha Zoroark',
#        'Pokemon Best Wishes!',
#        'Fullmetal Alchemist: The Sacred Star of Milos',
#        'Hoshi wo Ou Kodomo',
#        'Pokemon Best Wishes!: Victini to Kuroki Eiyuu Zekrom',
#        'Ao no Exorcist',
#        'Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.',
#        'Hotarubi no Mori e', 'Inazuma Eleven Go', 'Another',
#        'Code:Breaker', 'Ao no Exorcist Movie', 'Accel World',
#        'Pokemon Best Wishes! Season 2: Kyurem vs. Seikenshi',
#        'Zetsuen no Tempest', 'Pokemon Best Wishes! Season 2', 'Btooom!',
#        'Magi: The Labyrinth of Magic', 'Shingeki no Kyojin',
#        'Devil Survivor 2 The Animation', 'Kotonoha no Niwa',
#        'Kuroko no Basket 2nd Season', 'Gin no Saji', 'Log Horizon',
#        'Inazuma Eleven Go: Galaxy', 'Magi: The Kingdom of Magic',
#        'Fairy Tail x Rave', 'Pupa', 'No Game No Life',
#        'Sword Art Online: Extra Edition', 'Pokemon: The Origin',
#        'Noragami'], dtype=object)

# %%
df["name_tokens"] = df["name"].apply(lambda x: x.split())

name_sentences = df["name_tokens"].tolist()

# %% [markdown]
# #### training the word2vec model now on names

# %%
name_w2v = Word2Vec(sentences=name_sentences, vector_size=100, window=5, min_count=1, workers=4)

# %%
similar_anime = name_w2v.wv.most_similar("Pokemon", topn=5)
print("Anime similar to 'Naruto':", similar_anime)
# Out:
# Anime similar to 'Naruto': [('Giratina', 0.5691414475440979), ('Zekrom', 0.5569822192192078), ('Wishes!:', 0.5281127691268921), ('Victini', 0.5249943137168884), ('Vegeta', 0.5228556394577026)]
